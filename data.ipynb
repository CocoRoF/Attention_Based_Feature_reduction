# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler

from util import dataloader

# %%
dataloader.data_load('boston')
# Out:
# (array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  array([[24. ],
#         [21.6],
#         [34.7],
#         [33.4],
#         [36.2],
#         [28.7],
#         [22.9],
#         [27.1],
#         [16.5],
#         [18.9],
#         [15. ],
#         [18.9],
#         [21.7],
#         [20.4],
#         [18.2],
#         [19.9],
#         [23.1],
#         [17.5],
#         [20.2],
#         [18.2],
#         [13.6],
# ...

# %%
path = './Data/home-data-for-ml-course/'
train = pd.read_csv(path + "train_dropna.csv")
test = pd.read_csv(path + 'test_dropna.csv')

# %%
numeric_train = train.select_dtypes(include=['int', 'float'])
categorical_train = train.select_dtypes(include=['object'])

# %%
numeric_train[numeric_train==0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MSSubClass    0 non-null      float64
#  1   LotFrontage   0 non-null      float64
#  2   LotArea       0 non-null      float64
#  3   OverallQual   0 non-null      float64
#  4   OverallCond   0 non-null      float64
#  5   YearBuilt     0 non-null      float64
#  6   YearRemodAdd  0 non-null      float64
#  7   BsmtUnfSF     54 non-null     float64
#  8   TotalBsmtSF   0 non-null      float64
#  9   1stFlrSF      0 non-null      float64
#  10  GrLivArea     0 non-null      float64
#  11  FullBath      6 non-null      float64
#  12  BedroomAbvGr  4 non-null      float64
#  13  KitchenAbvGr  0 non-null      float64
#  14  TotRmsAbvGrd  0 non-null      float64
#  15  GarageYrBlt   0 non-null      float64
#  16  GarageCars    0 non-null      float64
# ...
